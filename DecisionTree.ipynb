# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('clean_steam_data.csv')

data.drop('Name', axis=1, inplace=True)

train, test = train_test_split(data, train_size=0.75,test_size= 0.25,random_state=123 )

y_train = train['Recommendations'].copy()

y_test  = test['Recommendations'].copy()

train.drop("Recommendations", axis=1, inplace=True)
test.drop( "Recommendations", axis=1, inplace=True)

x_train  = train.copy()

x_test   = test.copy()

# %%
tree_regressor = tree.DecisionTreeRegressor(criterion='squared_error')  # Set hyperparameters as needed

# Fit the model
tree_regressor.fit(x_train, y_train)

# # Make predictions for new data points
# X_new = np.linspace(0, 1, 100).reshape(-1, 1)
# y_pred = tree_regressor.predict(X_new)

# Visualize the decision tree (optional)
# (You can use graphviz or plot the tree structure)

columns = x_train.columns

plt.figure(figsize=(50, 30))
tree.plot_tree(tree_regressor, feature_names=columns, filled=True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

y_pred = tree_regressor.predict(x_test)

# Assuming y_test and y_pred are your actual and predicted values, respectively
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Absolute Error: 210.56
# Mean Squared Error: 28935152.39

# %%
tree_regressor = tree.DecisionTreeRegressor(min_samples_leaf=10, max_features='sqrt',criterion='squared_error')  # Set hyperparameters as needed

# Fit the model
tree_regressor.fit(x_train, y_train)

# # Make predictions for new data points
# X_new = np.linspace(0, 1, 100).reshape(-1, 1)
# y_pred = tree_regressor.predict(X_new)

# Visualize the decision tree (optional)
# (You can use graphviz or plot the tree structure)

columns = x_train.columns

plt.figure(figsize=(50, 30))
tree.plot_tree(tree_regressor, feature_names=columns, filled=True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

y_pred = tree_regressor.predict(x_test)

# Assuming y_test and y_pred are your actual and predicted values, respectively
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Absolute Error: 638.61
# Mean Squared Error: 80492655.08
